-- %% [markdown]
-- Catalog and Volumes creation

-- %%
CREATE CATALOG IF NOT EXISTS projeto_gov

-- %%
CREATE SCHEMA IF NOT EXISTS projeto_gov.bronze

-- %%
CREATE SCHEMA IF NOT EXISTS projeto_gov.silver

-- %%
CREATE SCHEMA IF NOT EXISTS projeto_gov.gold

-- %%
CREATE VOLUME IF NOT EXISTS projeto_gov.bronze.atletas

-- %%
DROP TABLE IF EXISTS projeto_gov.atletas
